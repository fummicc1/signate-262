# %%
import os
import numpy as np
import gc
import torch.distributed as dist
import pandas as pd
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP
import matplotlib.pyplot as plt
from typing import List
import cv2
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import transforms
import pandas as pd
import json
from PIL.Image import Image
import PIL
from tqdm import tqdm
from PIL import ImageDraw
from ultralytics import YOLO
import subprocess
from wandb_callback import callbacks

# %% [markdown]
# ## Run

# %%
mode = "modern"
use_trained_weights = False

# %%
if mode == "modern":
    kfolds = 4
    for i in range(2, kfolds):
        if i > 1:
            use_trained_weights = True
        data_path=f"/home/fummicc1/codes/signate/modern_book_kfold{i}.yaml"
        if not use_trained_weights:
            weight_path="/home/fummicc1/codes/signate/yolov5x6.pt"
        else:
            weight_path="/home/fummicc1/codes/signate/yolo_modern_weights-base.pt"
        out_path="/home/fummicc1/codes/signate/results/train_modern_book_yolov5"
        command = f"cd yolov5 && python train.py --img 800 --epochs 30 --data {data_path} --batch-size 8 --weights {weight_path} --project {out_path} --device 0,1,2,3"
        subprocess.run(command, shell=True)
        break
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: fummicc1. Use `wandb login --relogin` to force relogin
# train: weights=/home/fummicc1/codes/signate/yolov5x6.pt, cfg=, data=/home/fummicc1/codes/signate/modern_book.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=8, imgsz=800, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0,1,2,3, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/home/fummicc1/codes/signate/results/train_modern_book_yolov5, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2023-4-10 Python-3.8.13 torch-2.0.0+cu117 CUDA:0 (NVIDIA RTX A4000, 16117MiB)
#                                                     CUDA:1 (NVIDIA RTX A4000, 16117MiB)
#                                                     CUDA:2 (NVIDIA RTX A4000, 16117MiB)
#                                                     CUDA:3 (NVIDIA RTX A4000, 16115MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir /home/fummicc1/codes/signate/results/train_modern_book_yolov5', view at http://localhost:6006/
# wandb: wandb version 0.14.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.14.0
# wandb: Run data is saved locally in /home/fummicc1/codes/signate/yolov5/wandb/run-20230410_035513-5nfcvs36
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run clear-wave-4
# wandb: ⭐️ View project at https://wandb.ai/fummicc1/train_modern_book_yolov5
# wandb: 🚀 View run at https://wandb.ai/fummicc1/train_modern_book_yolov5/runs/5nfcvs36
# Overriding model.yaml nc=80 with nc=8
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Conv                      [3, 80, 6, 2, 2]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  4    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1  8   2259200  models.common.C3                        [320, 320, 8]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1 12  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   5531520  models.common.Conv                      [640, 960, 3, 2]
#   8                -1  4  11070720  models.common.C3                        [960, 960, 4]
#   9                -1  1  11061760  models.common.Conv                      [960, 1280, 3, 2]
#  10                -1  4  19676160  models.common.C3                        [1280, 1280, 4]
#  11                -1  1   4099840  models.common.SPPF                      [1280, 1280, 5]
#  12                -1  1   1230720  models.common.Conv                      [1280, 960, 1, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 8]  1         0  models.common.Concat                    [1]
#  15                -1  4  11992320  models.common.C3                        [1920, 960, 4, False]
#  16                -1  1    615680  models.common.Conv                      [960, 640, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 6]  1         0  models.common.Concat                    [1]
#  19                -1  4   5332480  models.common.C3                        [1280, 640, 4, False]
#  20                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  21                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  22           [-1, 4]  1         0  models.common.Concat                    [1]
#  23                -1  4   1335040  models.common.C3                        [640, 320, 4, False]
#  24                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  25          [-1, 20]  1         0  models.common.Concat                    [1]
#  26                -1  4   4922880  models.common.C3                        [640, 640, 4, False]
#  27                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  28          [-1, 16]  1         0  models.common.Concat                    [1]
#  29                -1  4  11377920  models.common.C3                        [1280, 960, 4, False]
#  30                -1  1   8296320  models.common.Conv                      [960, 960, 3, 2]
#  31          [-1, 12]  1         0  models.common.Concat                    [1]
#  32                -1  4  20495360  models.common.C3                        [1920, 1280, 4, False]
#  33  [23, 26, 29, 32]  1    124956  models.yolo.Detect                      [8, [[19, 27, 44, 40, 38, 94], [96, 68, 86, 152, 180, 137], [140, 301, 303, 264, 238, 542], [436, 615, 739, 380, 925, 792]], [320, 640, 960, 1280]]
# Model summary: 575 layers, 140102716 parameters, 140102716 gradients, 208.9 GFLOPs
#
# Transferred 955/963 items from /home/fummicc1/codes/signate/yolov5x6.pt
# AMP: checks passed ✅
# WARNING ⚠️ --img-size 800 must be multiple of max stride 64, updating to 832
# optimizer: SGD(lr=0.01) with parameter groups 159 weight(decay=0.0), 163 weight(decay=0.0005), 163 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://github.com/ultralytics/yolov5/issues/475 to get started.
# train: Scanning /home/fummicc1/codes/signate/train/modern/labels.cache... 2750 images, 40 backgrounds, 0 corrupt: 100%|██████████| 2750/2750 [00:00<?, ?it/s]
# val: Scanning /home/fummicc1/codes/signate/val/modern/labels.cache... 252 images, 0 backgrounds, 0 corrupt: 100%|██████████| 252/252 [00:00<?, ?it/s]
#
# AutoAnchor: 0.89 anchors/target, 0.501 Best Possible Recall (BPR). Anchors are a poor fit to dataset ⚠️, attempting to improve...
# AutoAnchor: WARNING ⚠️ Extremely small objects found: 85 of 97045 labels are <3 pixels in size
# AutoAnchor: Running kmeans for 12 anchors on 97045 points...
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.7814: 100%|██████████| 1000/1000 [00:03<00:00, 326.38it/s]
# AutoAnchor: thr=0.25: 0.9976 best possible recall, 3.94 anchors past thr
# AutoAnchor: n=12, img_size=832, metric_all=0.233/0.782-mean/best, past_thr=0.567-mean: 11,10, 47,9, 12,75, 96,10, 138,13, 258,11, 261,14, 15,322, 418,19, 19,469, 52,172, 693,526
# AutoAnchor: Done ✅ (optional: update model *.yaml to use these anchors in the future)
# Plotting labels to /home/fummicc1/codes/signate/results/train_modern_book_yolov5/exp2/labels.jpg...
# Image sizes 832 train, 832 val
# Using 7 dataloader workers
# Logging results to /home/fummicc1/codes/signate/results/train_modern_book_yolov5/exp2
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/39      4.15G      0.135    0.08699    0.05943        549        832:   0%|          | 0/344 [00:08<?, ?it/s]WARNING ⚠️ TensorBoard graph visualization failure Sizes of tensors must match except in dimension 1. Expected size 26 but got size 25 for tensor number 1 in the list.
#        0/39       5.3G     0.1082    0.08152    0.02742        254        832: 100%|██████████| 344/344 [02:40<00:00,  2.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.35it/s]
#                    all        252       9569      0.618      0.142      0.147     0.0685
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/39      6.33G     0.0919    0.07101    0.01216        404        832: 100%|██████████| 344/344 [02:26<00:00,  2.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.36it/s]
#                    all        252       9569      0.607      0.279      0.265      0.132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/39      6.33G    0.08859    0.06723    0.01027        165        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.30it/s]
#                    all        252       9569      0.648      0.334      0.327       0.13
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/39      6.33G    0.08329    0.06425   0.008751        236        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569      0.565      0.494      0.442      0.216
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/39      6.33G     0.0793    0.06318   0.007378        184        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.39it/s]
#                    all        252       9569      0.713      0.415      0.501      0.262
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/39      6.33G    0.07592    0.06072   0.006732        356        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569      0.714      0.454      0.506      0.244
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/39      6.33G    0.07429    0.05811   0.005859        356        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.787      0.464      0.555      0.274
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/39      6.33G    0.07284    0.05696   0.005396        300        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569      0.526      0.576       0.56      0.295
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/39      6.33G    0.07091    0.05585   0.005165        214        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569       0.65      0.581      0.622      0.338
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/39      6.33G    0.07018    0.05518   0.004764        323        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569      0.665      0.612      0.649      0.363
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/39      6.33G    0.06908    0.05343   0.004553        139        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569       0.72      0.553      0.559      0.266
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/39      6.33G    0.06908    0.05326   0.004274        450        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569      0.618      0.542       0.58      0.321
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/39      6.33G    0.06839    0.05427   0.004182        334        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.44it/s]
#                    all        252       9569      0.861      0.601      0.711      0.409
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/39      6.33G     0.0677    0.05098   0.004001        140        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569      0.844      0.583      0.694        0.4
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/39      6.33G     0.0669    0.05058   0.003853        313        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569      0.623      0.536      0.563       0.34
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/39      6.33G    0.06696     0.0507   0.003768        244        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.642      0.537      0.568      0.332
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/39      6.33G    0.06566    0.04989   0.003724        181        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569      0.723      0.665      0.672      0.391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/39      6.33G    0.06481    0.04862   0.003647        216        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.707      0.577      0.573      0.302
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/39      6.33G    0.06422    0.04847   0.003372        213        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.678      0.532       0.59      0.339
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/39      6.33G    0.06423    0.04852    0.00329        307        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.567      0.688      0.634      0.346
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/39      6.33G    0.06343    0.04773    0.00319        271        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.634      0.613      0.597      0.344
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/39      6.33G    0.06263    0.04686    0.00318        445        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569       0.71      0.614      0.607      0.353
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/39      6.33G    0.06324    0.04626   0.002989        540        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569       0.74      0.584      0.615      0.352
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/39      6.33G    0.06244    0.04665   0.002972        272        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569      0.649      0.542      0.598      0.337
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/39      6.33G    0.06226    0.04567   0.002862        371        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.40it/s]
#                    all        252       9569       0.73      0.569      0.619      0.366
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/39      6.33G    0.06128    0.04489   0.002818        360        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.44it/s]
#                    all        252       9569      0.749      0.593      0.595      0.366
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/39      6.33G    0.06149    0.04512   0.002785        337        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.835      0.526      0.597      0.356
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/39      6.33G    0.06057    0.04416   0.002635        260        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.748      0.619      0.619      0.382
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/39      6.33G    0.06057    0.04432   0.002647        356        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569      0.665      0.715      0.645      0.398
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/39      6.33G    0.06032    0.04425   0.002474        382        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569      0.663        0.7      0.649      0.396
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/39      6.33G    0.06002    0.04328   0.002497        172        832: 100%|██████████| 344/344 [02:24<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.825      0.606      0.691      0.444
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/39      6.33G    0.05921    0.04379   0.002326        385        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.685      0.523      0.583      0.359
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/39      6.33G    0.05876    0.04259   0.002275        279        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569       0.75      0.579      0.613      0.393
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/39      6.33G    0.05899    0.04258   0.002316        429        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569      0.734      0.611      0.599      0.383
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/39      6.33G    0.05868    0.04202   0.002237        397        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.41it/s]
#                    all        252       9569      0.679      0.647      0.642      0.413
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/39      6.33G    0.05828    0.04158   0.002105        381        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569      0.684      0.634      0.645      0.404
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/39      6.33G    0.05873    0.04175   0.002068        408        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569       0.82      0.539       0.64      0.404
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/39      6.33G    0.05772    0.04049   0.002106        294        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.42it/s]
#                    all        252       9569      0.756      0.571      0.601      0.386
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/39      6.33G     0.0574    0.04056   0.001939        419        832: 100%|██████████| 344/344 [02:25<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.43it/s]
#                    all        252       9569      0.816      0.534      0.616      0.381
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/39      6.33G    0.05715    0.04007   0.001941        260        832: 100%|██████████| 344/344 [02:25<00:00,  2.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:06<00:00,  2.44it/s]
#                    all        252       9569      0.665      0.541      0.623      0.401
#
# 40 epochs completed in 1.743 hours.
# Optimizer stripped from /home/fummicc1/codes/signate/results/train_modern_book_yolov5/exp2/weights/last.pt, 281.2MB
# Optimizer stripped from /home/fummicc1/codes/signate/results/train_modern_book_yolov5/exp2/weights/best.pt, 281.2MB
#
# Validating /home/fummicc1/codes/signate/results/train_modern_book_yolov5/exp2/weights/best.pt...
# Fusing layers...
# Model summary: 416 layers, 140038156 parameters, 0 gradients, 208.0 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 16/16 [00:21<00:00,  1.35s/it]
#                    all        252       9569      0.823      0.606      0.691      0.444
#              1_overall        252        252      0.992      0.971      0.995      0.911
#         4_illustration        252        134      0.881       0.88      0.877      0.441
#                5_stamp        252         15      0.814      0.667      0.719       0.45
#             6_headline        252        375      0.783      0.267      0.422      0.253
#              7_caption        252        132      0.868        0.4      0.618       0.32
#             8_textline        252       8659      0.811      0.559      0.636      0.313
#                9_table        252          2      0.614        0.5      0.566      0.417
# Results saved to /home/fummicc1/codes/signate/results/train_modern_book_yolov5/exp2
# wandb: Waiting for W&B process to finish... (success).

# %%
if mode == "old":
    kfolds = 4
    for i in range(1, kfolds):
        if i > 1:
            use_trained_weights = True
        data_path=f"/home/fummicc1/codes/signate/old_book_kfold{i}.yaml"
        if not use_trained_weights:
            weight_path="/home/fummicc1/codes/signate/yolov5x6.pt"
        else:
            weight_path="/home/fummicc1/codes/signate/yolo_old_weights-base.pt"        
        out_path="/home/fummicc1/codes/signate/results/train_old_book_yolov5"
        command = f"cd yolov5 && python train.py --img 800 --epochs 30 --data {data_path} --batch-size 8 --weights {weight_path} --project {out_path} --device 0,1,2,3"
        subprocess.run(command, shell=True)
        break
